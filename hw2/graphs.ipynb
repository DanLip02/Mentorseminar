# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
n = 2 * (10 ** 8)

# %%
python_numba_128 = np.array([
[8, 0.6],
[16, 0.4333],
[24, 0.3221],
[32, 0.33],
])
n = 128
python_numba_128 = pd.DataFrame(data=python_numba_128, columns=["p", "t"])
python_numba_128["Sp"] = python_numba_128["t"].iloc[0] / python_numba_128["t"]
python_numba_128["Ep"] = python_numba_128["Sp"] / python_numba_128["p"]
python_numba_128["FLOPS"] = 7 * 1000 * (n - 2) ** 2 / python_numba_128["t"]
python_numba_128
# Out:
#       p       t        Sp        Ep         FLOPS
# 0   8.0  0.6000  1.000000  0.125000  1.852200e+08
# 1  16.0  0.4333  1.384722  0.086545  2.564782e+08
# 2  24.0  0.3221  1.862776  0.077616  3.450233e+08
# 3  32.0  0.3300  1.818182  0.056818  3.367636e+08

# %%
python_numba_256 = np.array([
[8, 0.77],
[16, 0.43345],
[24, 0.33422],
[32, 0.3112345]
])
n = 256
python_numba_256 = pd.DataFrame(data=python_numba_256, columns=["p", "t"])
python_numba_256["Sp"] = python_numba_256["t"].iloc[0] / python_numba_256["t"]
python_numba_256["Ep"] = python_numba_256["Sp"] / python_numba_256["p"]
python_numba_256["FLOPS"] = 7 * 1000 * (n - 2) ** 2 / python_numba_256["t"]
python_numba_256
# Out:
#       p         t        Sp        Ep         FLOPS
# 0   8.0  0.770000  1.000000  0.125000  5.865091e+08
# 1  16.0  0.433450  1.776445  0.111028  1.041901e+09
# 2  24.0  0.334220  2.303872  0.095995  1.351242e+09
# 3  32.0  0.311235  2.474019  0.077313  1.451035e+09

# %%
python_numba_512 = np.array([
[8, 0.88445],
[16, 0.6534],
[24, 0.4522],
[32, 0.3775]
])
n = 512
python_numba_512 = pd.DataFrame(data=python_numba_512, columns=["p", "t"])
python_numba_512["Sp"] = python_numba_512["t"].iloc[0] / python_numba_512["t"]
python_numba_512["Ep"] = python_numba_512["Sp"] / python_numba_512["p"]
python_numba_512["FLOPS"] = 7 * 1000 * (n - 2) ** 2 / python_numba_512["t"]
python_numba_512
# Out:
#       p        t        Sp        Ep         FLOPS
# 0   8.0  0.88445  1.000000  0.125000  2.058567e+09
# 1  16.0  0.65340  1.353612  0.084601  2.786501e+09
# 2  24.0  0.45220  1.955882  0.081495  4.026316e+09
# 3  32.0  0.37750  2.342914  0.073216  4.823046e+09

# %%
python_numba_1024 = np.array([
[8,  2.1941],
[16, 1.4264],
[24, 1.0991],
[32, 0.9451]
])
n = 1024
python_numba_1024 = pd.DataFrame(data=python_numba_1024, columns=["p", "t"])
python_numba_1024["Sp"] = python_numba_1024["t"].iloc[0] / python_numba_1024["t"]
python_numba_1024["Ep"] = python_numba_1024["Sp"] / python_numba_1024["p"]
python_numba_1024["FLOPS"] = 7 * 1000 * (n - 2) ** 2 / python_numba_1024["t"]
python_numba_1024
# Out:
#       p       t        Sp        Ep         FLOPS
# 0   8.0  2.1941  1.000000  0.125000  3.332295e+09
# 1  16.0  1.4264  1.538208  0.096138  5.125763e+09
# 2  24.0  1.0991  1.996270  0.083178  6.652159e+09
# 3  32.0  0.9451  2.321553  0.072549  7.736100e+09

# %%
cpp_128 = np.array([
[8,  0.13312],
[16, 0.1123],
[24, 0.06651],
[32, 0.055123]])
n = 128
cpp_128 = pd.DataFrame(data=cpp_128, columns=["p", "t"])
cpp_128["Sp"] = cpp_128["t"].iloc[0] / cpp_128["t"]
cpp_128["Ep"] = cpp_128["Sp"] / cpp_128["p"]
cpp_128["FLOPS"] = 7 * 1000 * (n - 2) ** 2 / cpp_128["t"]
cpp_128
# Out:
#       p         t        Sp        Ep         FLOPS
# 0   8.0  0.133120  1.000000  0.125000  8.348257e+08
# 1  16.0  0.112300  1.185396  0.074087  9.895993e+08
# 2  24.0  0.066510  2.001504  0.083396  1.670907e+09
# 3  32.0  0.055123  2.414963  0.075468  2.016073e+09

# %%
cpp_256 = np.array([
[8,  0.19],
[16, 0.13],
[24, 0.11323],
[32, 0.07433]])
n = 256
cpp_256 = pd.DataFrame(data=cpp_256, columns=["p", "t"])
cpp_256["Sp"] = cpp_256["t"].iloc[0] / cpp_256["t"]
cpp_256["Ep"] = cpp_256["Sp"] / cpp_256["p"]
cpp_256["FLOPS"] = 7 * 1000 * (n - 2) ** 2 / cpp_256["t"]
cpp_256
# Out:
#       p        t        Sp        Ep         FLOPS
# 0   8.0  0.19000  1.000000  0.125000  2.376905e+09
# 1  16.0  0.13000  1.461538  0.091346  3.473938e+09
# 2  24.0  0.11323  1.678001  0.069917  3.988448e+09
# 3  32.0  0.07433  2.556168  0.079880  6.075770e+09

# %%
cpp_512 = np.array([
[8,  0.323341],
[16, 0.1944],
[24, 0.1544123],
[32, 0.10343]])
n = 512
cpp_512 = pd.DataFrame(data=cpp_512, columns=["p", "t"])
cpp_512["Sp"] = cpp_512["t"].iloc[0] / cpp_512["t"]
cpp_512["Ep"] = cpp_512["Sp"] / cpp_512["p"]
cpp_512["FLOPS"] = 7 * 1000 * (n - 2) ** 2 / cpp_512["t"]
cpp_512
# Out:
#       p         t        Sp        Ep         FLOPS
# 0   8.0  0.323341  1.000000  0.125000  5.630897e+09
# 1  16.0  0.194400  1.663277  0.103955  9.365741e+09
# 2  24.0  0.154412  2.094011  0.087250  1.179116e+10
# 3  32.0  0.103430  3.126182  0.097693  1.760321e+10

# %%
pycuda_128 = np.array([
[8,  0.5554],
[16, 0.345],
[24, 0.3212],
[32, 0.3321232]])
n = 128
pycuda_128 = pd.DataFrame(data=pycuda_128, columns=["p", "t"])
pycuda_128["Sp"] = cpp_512["t"].iloc[0] / pycuda_128["t"]
pycuda_128["Ep"] = cpp_512["Sp"] / pycuda_128["p"]
pycuda_128["FLOPS"] = 7 * 1000 * (n - 2) ** 2 / pycuda_128["t"]
pycuda_128
# Out:
#       p       t        Sp        Ep         FLOPS
# 0   8.0  0.5554  0.582177  0.125000  2.000936e+08
# 1  16.0  0.3450  0.937220  0.103955  3.221217e+08
# 2  24.0  0.3220  1.004165  0.087250  3.451304e+08
# 3  32.0  0.3322  0.973332  0.097693  3.345334e+08

# %%
pycuda_256 = np.array([
[8,  0.6652],
[16, 0.4124],
[24, 0.33112],
[32, 0.28313]])
n = 256
pycuda_256 = pd.DataFrame(data=pycuda_256, columns=["p", "t"])
pycuda_256["Sp"] = pycuda_256["t"].iloc[0] / pycuda_256["t"]
pycuda_256["Ep"] = pycuda_256["Sp"] / pycuda_256["p"]
pycuda_256["FLOPS"] = 7 * 1000 * (n - 2) ** 2 / pycuda_256["t"]
pycuda_256
# Out:
#       p        t        Sp        Ep         FLOPS
# 0   8.0  0.66520  1.000000  0.125000  6.789116e+08
# 1  16.0  0.41240  1.612997  0.100812  1.095082e+09
# 2  24.0  0.33112  2.008939  0.083706  1.363892e+09
# 3  32.0  0.28313  2.349451  0.073420  1.595069e+09

# %%
pycuda_512 = np.array([
[8,  0.83],
[16, 0.714514],
[24, 0.45234],
[32, 0.3654234]])
n = 512
pycuda_512 = pd.DataFrame(data=pycuda_512, columns=["p", "t"])
pycuda_512["Sp"] = pycuda_512["t"].iloc[0] / pycuda_512["t"]
pycuda_512["Ep"] = pycuda_512["Sp"] / pycuda_512["p"]
pycuda_512["FLOPS"] = 7 * 1000 * (n - 2) ** 2 / pycuda_512["t"]
pycuda_512
# Out:
#       p         t        Sp        Ep         FLOPS
# 0   8.0  0.830000  1.000000  0.125000  2.193614e+09
# 1  16.0  0.714514  1.161629  0.072602  2.548166e+09
# 2  24.0  0.452340  1.834903  0.076454  4.025070e+09
# 3  32.0  0.365423  2.271338  0.070979  4.982440e+09

# %%
col = "t"

plt.figure(figsize=(10, 6))
plt.plot(pycuda_128["p"], pycuda_128[col], marker='o', linestyle='--', label='pycuda_128')
plt.plot(pycuda_256["p"], pycuda_256[col], marker='o', linestyle='--', label='pycuda_256')
plt.plot(pycuda_512["p"], pycuda_512[col], marker='o', linestyle='--', label='pycuda_512')
plt.plot(python_numba_128["p"], python_numba_128[col], marker='o', linestyle='--', label='python_numba_128')
plt.plot(python_numba_256["p"], python_numba_256[col], marker='o', linestyle='--', label='python_numba_256')
plt.plot(python_numba_512["p"], python_numba_512[col], marker='o', linestyle='--', label='python_numba_512')
plt.plot(cpp_128["p"], cpp_128[col], marker='o', linestyle='--', label='cpp_128')
plt.plot(cpp_256["p"], cpp_256[col], marker='o', linestyle='--', label='cpp_256')
plt.plot(cpp_512["p"], cpp_512[col], marker='o', linestyle='--', label='cpp_512')
plt.xlabel("p")
plt.ylabel("T")
plt.title("Tp")
plt.grid(True)
plt.legend()
plt.show()

# %%
col = "t"

plt.figure(figsize=(10, 6))
plt.plot(pycuda_128["p"], pycuda_128[col], marker='o', linestyle='--', label='pycuda_128')
plt.plot(pycuda_256["p"], pycuda_256[col], marker='o', linestyle='--', label='pycuda_256')
plt.plot(pycuda_512["p"], pycuda_512[col], marker='o', linestyle='--', label='pycuda_512')
plt.plot(python_numba_128["p"], python_numba_128[col], marker='o', linestyle='--', label='python_numba_128')
plt.plot(python_numba_256["p"], python_numba_256[col], marker='o', linestyle='--', label='python_numba_256')
plt.plot(python_numba_512["p"], python_numba_512[col], marker='o', linestyle='--', label='python_numba_512')
plt.plot(cpp_128["p"], cpp_128[col], marker='o', linestyle='--', label='cpp_128')
plt.plot(cpp_256["p"], cpp_256[col], marker='o', linestyle='--', label='cpp_256')
plt.plot(cpp_512["p"], cpp_512[col], marker='o', linestyle='--', label='cpp_512')
plt.xlabel("p")
plt.ylabel("T")
plt.title("Tp")
plt.grid(True)
plt.legend()
plt.show()

# %%
col = "Ep"

plt.figure(figsize=(10, 6))
plt.plot(pycuda_128["p"], pycuda_128[col], marker='o', linestyle='--', label='pycuda_128')
plt.plot(pycuda_256["p"], pycuda_256[col], marker='o', linestyle='--', label='pycuda_256')
plt.plot(pycuda_512["p"], pycuda_512[col], marker='o', linestyle='--', label='pycuda_512')
plt.plot(python_numba_128["p"], python_numba_128[col], marker='o', linestyle='--', label='python_numba_128')
plt.plot(python_numba_256["p"], python_numba_256[col], marker='o', linestyle='--', label='python_numba_256')
plt.plot(python_numba_512["p"], python_numba_512[col], marker='o', linestyle='--', label='python_numba_512')
plt.plot(cpp_128["p"], cpp_128[col], marker='o', linestyle='--', label='cpp_128')
plt.plot(cpp_256["p"], cpp_256[col], marker='o', linestyle='--', label='cpp_256')
plt.plot(cpp_512["p"], cpp_512[col], marker='o', linestyle='--', label='cpp_512')
plt.xlabel("p")
plt.ylabel("E")
plt.title("Ep")
plt.grid(True)
plt.legend()
plt.show()

# %%
col = "FLOPS"

plt.figure(figsize=(10, 6))
plt.plot(pycuda_128["p"], pycuda_128[col], marker='o', linestyle='--', label='pycuda_128')
plt.plot(pycuda_256["p"], pycuda_256[col], marker='o', linestyle='--', label='pycuda_256')
plt.plot(pycuda_512["p"], pycuda_512[col], marker='o', linestyle='--', label='pycuda_512')
plt.plot(python_numba_128["p"], python_numba_128[col], marker='o', linestyle='--', label='python_numba_128')
plt.plot(python_numba_256["p"], python_numba_256[col], marker='o', linestyle='--', label='python_numba_256')
plt.plot(python_numba_512["p"], python_numba_512[col], marker='o', linestyle='--', label='python_numba_512')
plt.plot(cpp_128["p"], cpp_128[col], marker='o', linestyle='--', label='cpp_128')
plt.plot(cpp_256["p"], cpp_256[col], marker='o', linestyle='--', label='cpp_256')
plt.plot(cpp_512["p"], cpp_512[col], marker='o', linestyle='--', label='cpp_512')
plt.xlabel("p")
plt.ylabel("FPLOP")
plt.title("FLOPS")
plt.grid(True)
plt.legend()
plt.show()

# %%
col = "Sp"

plt.figure(figsize=(10, 6))
plt.plot(pycuda_128["p"], pycuda_128[col], marker='o', linestyle='--', label='pycuda_128')
plt.plot(pycuda_256["p"], pycuda_256[col], marker='o', linestyle='--', label='pycuda_256')
plt.plot(pycuda_512["p"], pycuda_512[col], marker='o', linestyle='--', label='pycuda_512')
plt.plot(python_numba_128["p"], python_numba_128[col], marker='o', linestyle='--', label='python_numba_128')
plt.plot(python_numba_256["p"], python_numba_256[col], marker='o', linestyle='--', label='python_numba_256')
plt.plot(python_numba_512["p"], python_numba_512[col], marker='o', linestyle='--', label='python_numba_512')
plt.plot(cpp_128["p"], cpp_128[col], marker='o', linestyle='--', label='cpp_128')
plt.plot(cpp_256["p"], cpp_256[col], marker='o', linestyle='--', label='cpp_256')
plt.plot(cpp_512["p"], cpp_512[col], marker='o', linestyle='--', label='cpp_512')
plt.xlabel("p")
plt.ylabel("Sp")
plt.title("Sp")
plt.grid(True)
plt.legend()
plt.show()

# %%
~
